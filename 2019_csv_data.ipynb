# %%
import pandas as pd

# %%
january = "2019_data/JC-201901-citibike-tripdata.csv"
february = "2019_data/JC-201902-citibike-tripdata.csv"
march = "2019_data/JC-201903-citibike-tripdata.csv"
april = "2019_data/JC-201904-citibike-tripdata.csv"
may = "2019_data/JC-201905-citibike-tripdata.csv"
june = "2019_data/JC-201906-citibike-tripdata.csv"
july = "2019_data/JC-201907-citibike-tripdata.csv"
august = "2019_data/JC-201908-citibike-tripdata.csv"
september = "2019_data/JC-201909-citibike-tripdata.csv"
october = "2019_data/JC-201910-citibike-tripdata.csv"
november = "2019_data/JC-201911-citibike-tripdata.csv"
december = "2019_data/JC-201912-citibike-tripdata.csv"
January = pd.read_csv(january)
February = pd.read_csv(february)
March = pd.read_csv(march)
April = pd.read_csv(april)
May = pd.read_csv(may)
June = pd.read_csv(june)
July = pd.read_csv(july)
August = pd.read_csv(august)
September = pd.read_csv(september)
October = pd.read_csv(october)
November = pd.read_csv(november)
December = pd.read_csv(december)

# %%
new_df = January.groupby("start station name").mean()
new_df["Month"] = "January"
new_df["Year"] = 2019
january_df = new_df
january_df
# Out:
#                          tripduration  start station id  \
# start station name
# 5 Corners Library          559.885714            3220.0
# Astor Place                505.802521            3280.0
# Baldwin at Montgomery      630.171296            3225.0
# Bergen Ave                 523.220000            3679.0
# Brunswick & 6th            387.592593            3269.0
# Brunswick St               328.598698            3209.0
# Christ Hospital            521.940741            3212.0
# City Hall                  387.898608            3185.0
# Columbus Drive             358.782313            3275.0
# Communipaw & Berry Lane    758.000000            3277.0
# Dey St                     402.893617            3201.0
# Dixon Mills                309.414248            3279.0
# Essex Light Rail           458.543807            3214.0
# Exchange Place             404.317013            3183.0
# Fairmount Ave              451.833333            3678.0
# ...

# %%
new_df = February.groupby("start station name").mean()
new_df["Month"] = "February"
new_df["Year"] = 2019
february_df = new_df
february_df
# Out:
#                          tripduration  start station id  \
# start station name
# 5 Corners Library          497.054054            3220.0
# Astor Place                537.942982            3280.0
# Baldwin at Montgomery      564.778846            3225.0
# Bergen Ave                 511.751445            3679.0
# Brunswick & 6th            394.648230            3269.0
# Brunswick St               407.986328            3209.0
# Christ Hospital            509.834951            3212.0
# City Hall                  444.352113            3185.0
# Columbus Drive             360.778291            3275.0
# Communipaw & Berry Lane    792.288462            3277.0
# Dey St                     547.096154            3201.0
# Dixon Mills                265.710383            3279.0
# Essex Light Rail           433.245552            3214.0
# Exchange Place            1096.416116            3183.0
# Fairmount Ave              432.034483            3678.0
# ...

# %%
new_df = March.groupby("start station name").mean()
new_df["Month"] = "March"
new_df["Year"] = 2019
march_df = new_df
march_df
# Out:
#                          tripduration  start station id  \
# start station name
# 5 Corners Library          610.662921            3220.0
# Astor Place                607.902344            3280.0
# Baldwin at Montgomery      586.500000            3225.0
# Bergen Ave                 561.847458            3679.0
# Brunswick & 6th            391.033546            3269.0
# Brunswick St               358.075885            3209.0
# Christ Hospital            666.541667            3212.0
# City Hall                  762.978784            3185.0
# Columbus Drive             541.317125            3275.0
# Communipaw & Berry Lane   1627.623529            3277.0
# Dey St                     637.380000            3201.0
# Dixon Mills                377.093822            3279.0
# Essex Light Rail           609.831099            3214.0
# Exchange Place             744.683254            3183.0
# Fairmount Ave              490.410112            3678.0
# ...

# %%
new_df = April.groupby("start station name").mean()
new_df["Month"] = "April"
new_df["Year"] = 2019
april_df = new_df
april_df
# Out:
#                          tripduration  start station id  \
# start station name
# 5 Corners Library          701.846429            3220.0
# Astor Place                784.096273            3280.0
# Baldwin at Montgomery      699.893372            3225.0
# Bergen Ave                 506.415162            3679.0
# Brunswick & 6th            413.569136            3269.0
# Brunswick St               412.748580            3209.0
# Christ Hospital            567.545064            3212.0
# City Hall                  628.472540            3185.0
# Columbus Drive             475.819466            3275.0
# Communipaw & Berry Lane    948.703704            3277.0
# Dey St                     721.680851            3201.0
# Dixon Mills                444.542593            3279.0
# Essex Light Rail           512.503030            3214.0
# Exchange Place             695.677912            3183.0
# Fairmount Ave              623.976471            3678.0
# ...

# %%
new_df = May.groupby("start station name").mean()
new_df["Month"] = "May"
new_df["Year"] = 2019
may_df = new_df
may_df
# Out:
#                             tripduration  start station id  \
# start station name
# 5 Corners Library             713.550218            3220.0
# Astor Place                  2019.324713            3280.0
# Baldwin at Montgomery         896.143959            3225.0
# Bergen Ave                    625.986441            3679.0
# Brunswick & 6th               626.133508            3269.0
# Brunswick St                  420.837086            3209.0
# Christ Hospital               666.332016            3212.0
# City Hall                     657.349733            3185.0
# Columbus Drive                589.297744            3275.0
# Communipaw & Berry Lane      3356.763158            3277.0
# Dey St                        827.784483            3201.0
# Dixon Mills                   356.558219            3279.0
# Essex Light Rail              892.807309            3214.0
# Exchange Place                714.716338            3183.0
# Fairmount Ave                 537.730408            3678.0
# ...

# %%
new_df = June.groupby("start station name").mean()
new_df["Month"] = "June"
new_df["Year"] = 2019
june_df = new_df
june_df
# Out:
#                             tripduration  start station id  \
# start station name
# 5 Corners Library            1015.510373            3220.0
# Astor Place                   790.604534            3280.0
# Baldwin at Montgomery         963.798165            3225.0
# Bergen Ave                    746.716981            3679.0
# Brunswick & 6th               556.039846            3269.0
# Brunswick St                  531.912302            3209.0
# Christ Hospital               738.048148            3212.0
# City Hall                     940.740909            3185.0
# Columbus Drive                603.825221            3275.0
# Communipaw & Berry Lane      1933.174359            3277.0
# Dey St                        747.238095            3201.0
# Dixon Mills                   566.816949            3279.0
# Essex Light Rail             1050.984694            3214.0
# Fairmount Ave                 476.224615            3678.0
# Glenwood Ave                  594.134969            3677.0
# ...

# %%
new_df = July.groupby("start station name").mean()
new_df["Month"] = "July"
new_df["Year"] = 2019
july_df = new_df
july_df
# Out:
#                             tripduration  start station id  \
# start station name
# 5 Corners Library             657.142857            3220.0
# Astor Place                   674.504451            3280.0
# Baldwin at Montgomery         782.861171            3225.0
# Bergen Ave                    587.131737            3679.0
# Brunswick & 6th               564.223827            3269.0
# Brunswick St                  455.166478            3209.0
# Christ Hospital               813.118644            3212.0
# City Hall                    1066.547118            3185.0
# Columbus Dr at Exchange Pl   1058.934441            3792.0
# Columbus Drive                588.962596            3275.0
# Communipaw & Berry Lane      1171.097276            3277.0
# Dey St                        864.465409            3201.0
# Dixon Mills                   394.257104            3279.0
# Essex Light Rail              609.377600            3214.0
# Fairmount Ave                 623.614583            3678.0
# ...

# %%
new_df = August.groupby("start station name").mean()
new_df["Month"] = "August"
new_df["Year"] = 2019
august_df = new_df
august_df
# Out:
#                             tripduration  start station id  \
# start station name
# 5 Corners Library             784.574675            3220.0
# Astor Place                   679.922886            3280.0
# Baldwin at Montgomery         835.021552            3225.0
# Bergen Ave                   4214.584615            3679.0
# Brunswick & 6th               563.496572            3269.0
# Brunswick St                  573.206478            3209.0
# Christ Hospital               704.424658            3212.0
# City Hall                    2074.884859            3185.0
# Columbus Dr at Exchange Pl    623.478796            3792.0
# Columbus Drive                593.549758            3275.0
# Communipaw & Berry Lane      1278.503650            3277.0
# Dey St                        802.677725            3201.0
# Dixon Mills                   386.122085            3279.0
# Essex Light Rail              603.419506            3214.0
# Fairmount Ave                 637.252525            3678.0
# ...

# %%
new_df = September.groupby("start station name").mean()
new_df["Month"] = "September"
new_df["Year"] = 2019
september_df = new_df
september_df
# Out:
#                             tripduration  start station id  \
# start station name
# 5 Corners Library             786.882883            3220.0
# Astor Place                  1828.959016            3280.0
# Baldwin at Montgomery         785.775120            3225.0
# Bergen Ave                    631.160714            3679.0
# Brunswick & 6th               551.587121            3269.0
# Brunswick St                  514.906286            3209.0
# Christ Hospital               768.515385            3212.0
# City Hall                     750.535889            3185.0
# Columbus Dr at Exchange Pl   1284.091530            3792.0
# Columbus Drive                614.602004            3275.0
# Communipaw & Berry Lane      1183.383803            3277.0
# Dey St                        654.905882            3201.0
# Dixon Mills                   405.746356            3279.0
# Essex Light Rail              671.295970            3214.0
# Fairmount Ave                 766.174142            3678.0
# ...

# %%
new_df = October.groupby("start station name").mean()
new_df["Month"] = "October"
new_df["Year"] = 2019
october_df = new_df
october_df
# Out:
#                             tripduration  start station id  \
# start station name
# 5 Corners Library             603.068441            3220.0
# Astor Place                   727.508929            3280.0
# Baldwin at Montgomery         609.728205            3225.0
# Bergen Ave                    474.630252            3679.0
# Brunswick & 6th               599.172253            3269.0
# Brunswick St                  420.838565            3209.0
# Christ Hospital               577.449219            3212.0
# City Hall                     545.344468            3185.0
# Columbus Dr at Exchange Pl    551.530025            3792.0
# Columbus Drive                429.171301            3275.0
# Communipaw & Berry Lane      1021.113861            3277.0
# Dey St                        603.671642            3201.0
# Dixon Mills                   335.334722            3279.0
# Essex Light Rail              509.908197            3214.0
# Fairmount Ave                 507.013055            3678.0
# ...

# %%
new_df = November.groupby("start station name").mean()
new_df["Month"] = "November"
new_df["Year"] = 2019
november_df = new_df
november_df
# Out:
#                             tripduration  start station id  \
# start station name
# 5 Corners Library           14336.651007            3220.0
# Astor Place                   666.793333            3280.0
# Baldwin at Montgomery         567.583333            3225.0
# Bergen Ave                    532.796491            3679.0
# Brunswick & 6th               406.356164            3269.0
# Brunswick St                  510.859375            3209.0
# Christ Hospital               558.943182            3212.0
# City Hall                     461.446176            3185.0
# Columbus Dr at Exchange Pl    511.914858            3792.0
# Columbus Drive               1163.248074            3275.0
# Communipaw & Berry Lane       853.811881            3277.0
# Dey St                        537.897436            3201.0
# Dixon Mills                   275.031496            3279.0
# Essex Light Rail              468.505695            3214.0
# Fairmount Ave                 450.569343            3678.0
# ...

# %%
new_df = December.groupby("start station name").mean()
new_df["Month"] = "December"
new_df["Year"] = 2019
december_df = new_df
december_df
# Out:
#                             tripduration  start station id  \
# start station name
# 5 Corners Library             478.072917            3220.0
# Astor Place                   549.854962            3280.0
# Baldwin at Montgomery         536.149733            3225.0
# Bergen Ave                    496.469767            3679.0
# Brunswick & 6th               430.229665            3269.0
# Brunswick St                  411.199552            3209.0
# Christ Hospital               562.186992            3212.0
# City Hall                    1239.520661            3185.0
# Columbus Dr at Exchange Pl    518.838621            3792.0
# Columbus Drive                368.599548            3275.0
# Communipaw & Berry Lane       846.916667            3277.0
# Dey St                        827.962963            3201.0
# Dixon Mills                   299.447301            3279.0
# Essex Light Rail              467.462745            3214.0
# Fairmount Ave                 461.114155            3678.0
# ...

# %%
combined_df = january_df.append(february_df)
combined_df = combined_df.append(march_df)
combined_df = combined_df.append(april_df)
combined_df = combined_df.append(may_df)
combined_df = combined_df.append(june_df)
combined_df = combined_df.append(july_df)
combined_df = combined_df.append(august_df)
combined_df = combined_df.append(september_df)
combined_df = combined_df.append(october_df)
combined_df = combined_df.append(november_df)
combined_df = combined_df.append(december_df)
combined_df
# Out:
#                        tripduration  start station id  start station latitude  \
# start station name
# 5 Corners Library        559.885714            3220.0               40.734961
# Astor Place              505.802521            3280.0               40.719282
# Baldwin at Montgomery    630.171296            3225.0               40.723659
# Bergen Ave               523.220000            3679.0               40.722104
# Brunswick & 6th          387.592593            3269.0               40.726012
# ...                             ...               ...                     ...
# Union St                 834.711111            3191.0               40.718211
# Van Vorst Park           539.035354            3213.0               40.718489
# Warren St                400.507782            3187.0               40.721124
# Washington St            435.058537            3638.0               40.724294
# York St                  478.118343            3481.0               40.716490
#
# ...

# %%
combined_df.to_csv('citi_bike_2019data.csv')

# %%
test_2019 = pd.read_csv('citi_bike_2019data.csv')
test_2020 = pd.read_csv('citi_bike_2020data.csv')
combined_df = test_2019.append(test_2020)
combined_df
# Out:
#         start station name  tripduration  start station id  \
# 0        5 Corners Library    559.885714            3220.0
# 1              Astor Place    505.802521            3280.0
# 2    Baldwin at Montgomery    630.171296            3225.0
# 3               Bergen Ave    523.220000            3679.0
# 4          Brunswick & 6th    387.592593            3269.0
# ..                     ...           ...               ...
# 608               Union St  65548.906250            3191.0
# 609         Van Vorst Park    807.215517            3213.0
# 610              Warren St    888.251948            3187.0
# 611          Washington St   1592.148571            3638.0
# 612                York St   1128.812500            3481.0
#
#      start station latitude  start station longitude  end station id  \
# 0                 40.734961               -74.059503     3238.400000
# 1                 40.719282               -74.071262     3220.689076
# ...

# %%
combined_df.to_csv('final_citi_bike_data.csv')
